# %% [markdown]
# Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Dataset

# %%
ds=pd.read_csv('Data.csv')
x=ds.iloc[:,:-1].values
y=ds.iloc[:,-1].values
print(x)

print(y)

# %% [markdown]
# Splitting Datasets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)

# %% [markdown]
# Random Forest regression

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor(n_estimators=10,random_state=0)
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=10, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %% [markdown]
#   Predicting RFR results

# %%
ypred=rfr.predict(x_test)
np.set_printoptions(precision=3)
print(np.concatenate((ypred.reshape(len(ypred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[434.838 431.23 ]
#  [456.367 460.01 ]
#  [463.082 461.14 ]
#  ...
#  [449.653 453.66 ]
#  [462.887 465.49 ]
#  [443.942 446.09 ]]

# %% [markdown]
# Checking Efficiency

# %%
from sklearn.metrics import r2_score
print("Efficiency of Random Forest reg. on given dataset")
r2_score(ypred,y_test)
# Out:
# Efficiency of Random Forest reg. on given dataset
# 0.9507253646052335
